# %% [markdown]
# <a href="https://colab.research.google.com/github/robertoricci/Analise-Financeira/blob/main/NOTEBOOK_ETL_B3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#instalar bibliotecas necessarias 
# !pip install SQLAlchemy
# !pip install psycopg2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: SQLAlchemy in /usr/local/lib/python3.7/dist-packages (1.4.44)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from SQLAlchemy) (4.13.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from SQLAlchemy) (2.0.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->SQLAlchemy) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->SQLAlchemy) (3.10.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: psycopg2 in /usr/local/lib/python3.7/dist-packages (2.9.5)

# %%
import requests
from base64 import b64encode
import pandas as pd
import sqlalchemy as sql

# %%
#criar conexão com o banco Postgres

conn = 'suaconexao'
sql_conn = sql.create_engine(conn)

# %%
# Função para obter empresas do IBOV ou IFIX
def getEmpIndex(seg=2,index='IBOV'):
    # cria os parâmetros 
    # index: IBOV 
    #        IFIX

    #segment:1 informações sem segmento
    #       :2 informações com segmento

    params = {"language":"pt-br","pageNumber":1,"pageSize":200,"index":index,"segment":seg}
    
    # codifica os parâmetros em base64
    params = bytes(str(params), encoding="ascii")
    string = b64encode(params)
    string = string.decode()
   #{"language":"pt-br","pageNumber":1,"pageSize":120,"index":"IBOV","segment":"1"}

    r = requests.get('https://sistemaswebb3-listados.b3.com.br/indexProxy/indexCall/GetPortfolioDay/'+ string)
    return r.json()

# %%
index = getEmpIndex()

# %%
df_ibov = pd.DataFrame.from_dict(index['results'])

# %%
#df_ibov[['segment','cod','asset','type']] = df_ibov[['segment','cod','asset','type']].astype(str)
#df_ibov['part'].apply(lambda x: float(x.replace(',', '.')))
#df_ibov['partAcum'].apply(lambda x: float(x.replace(',', '.')))
#df_ibov['theoricalQty'].apply(lambda x: float(x))
# df_ibov['segment'] = df_ibov['segment'].astype(str)
# df_ibov['cod'] = df_ibov['cod'].astype(str)
# df_ibov['asset'] =df_ibov['asset'].astype(str)
# df_ibov['type'] = df_ibov['type'].astype(str)
df_ibov['part']= df_ibov['part'].str.replace(',', '.',regex=True).astype(float)
df_ibov['partAcum'] = df_ibov['partAcum'].str.replace(',', '.',regex=True).astype(float)
df_ibov['theoricalQty'] = df_ibov['theoricalQty'].str.replace('.', '',regex=True).astype(int)

# %%
df_ibov.dtypes
# Out:
# segment          object
# cod              object
# asset            object
# type             object
# part            float64
# partAcum        float64
# theoricalQty      int64
# dtype: object

# %%
#altera tipos das colunas

# %%
df_ibov.set_index('cod')
# Out:
#                                 segment         asset        type   part  \
# cod
# WEGE3        Bens Indls / Máqs e Equips           WEG  ON      NM  2.811
# EMBR3       Bens Indls / Mat Transporte       EMBRAER  ON      NM  0.478
# AZUL4             Bens Indls/Transporte          AZUL  PN      N2  0.198
# CCRO3             Bens Indls/Transporte        CCR SA  ON  ED  NM  0.607
# ECOR3             Bens Indls/Transporte   ECORODOVIAS  ON      NM  0.074
# ...                                 ...           ...         ...    ...
# ENGI11  Utilidade Públ / Energ Elétrica      ENERGISA  UNT     N2  0.545
# ENEV3   Utilidade Públ / Energ Elétrica         ENEVA  ON      NM  0.994
# EGIE3   Utilidade Públ / Energ Elétrica  ENGIE BRASIL  ON      NM  0.488
# EQTL3   Utilidade Públ / Energ Elétrica    EQUATORIAL  ON      NM  1.518
# TAEE11  Utilidade Públ / Energ Elétrica         TAESA  UNT     N2  0.408
#
#         partAcum  theoricalQty
# cod
# WEGE3      2.811    1481593024
# EMBR3      0.478     734632205
# AZUL4      2.106     327646296
# CCRO3      2.106    1115681435
# ECOR3      2.106     333657615
# ...          ...           ...
# ENGI11     9.638     248477689
# ENEV3      9.638    1561135009
# EGIE3      9.638     255208461
# EQTL3      9.638    1100513485
# TAEE11     9.638     218568234
#
# [92 rows x 6 columns]

# %%
df_ibov.dtypes
# Out:
# segment         object
# cod             object
# asset           object
# type            object
# part            object
# partAcum        object
# theoricalQty    object
# dtype: object

# %%
from sqlalchemy.sql.sqltypes import VARCHAR
#inserir no tabela
dtype = {'cod': sql.VARCHAR(10),'segment':sql.VARCHAR(100),'asset':sql.VARCHAR(20),'type':sql.VARCHAR(10),'part':sql.FLOAT,'partAcum':sql.FLOAT,'theoricalQty': sql.INT} 
df_ibov.to_sql('ibov_b3',sql_conn,schema='public',if_exists='append',index = False, method="multi",chunksize=999,dtype= dtype)

# %% [markdown]
# #importar dados do IFIX

# %%
#buscar index do ifix
index_ifix = getEmpIndex(seg=2,index='IFIX')

# %%
#tranformar em dataframe
df_ifix = pd.DataFrame.from_dict(index_ifix['results'])

# %%
#converter colunas para formato desejado
df_ifix['part']= df_ifix['part'].str.replace(',', '.',regex=True).astype(float)
df_ifix['partAcum'] = df_ifix['partAcum'].str.replace(',', '.',regex=True).astype(float)
df_ifix['theoricalQty'] = df_ifix['theoricalQty'].str.replace('.', '',regex=True).astype(int)

# %%
df_ifix.dtypes
# Out:
# segment          object
# cod              object
# asset            object
# type             object
# part            float64
# partAcum        float64
# theoricalQty      int64
# dtype: object

# %%
from sqlalchemy.sql.sqltypes import VARCHAR
#Criar tabela e inserir os dados
dtype = {'cod': VARCHAR(10),
         'segment':VARCHAR(100),
         'asset':VARCHAR(20),
         'type':VARCHAR(10),
         'part':FLOAT,
         'partAcum':FLOAT,
         'theoricalQty': INT} 
df_ifix.to_sql('ifix_b3',sql_conn,schema='public',if_exists='append',index = False, method="multi",chunksize=999,dtype= dtype)

# %%
ifix_cursor = sql_conn.execute("SELECT * FROM public.ifix_b3")  
for r in ifix_cursor:  
    print(r)
# Out:
# ('Financ e Outros / Fundos', 'CACR11', 'CARTESIA FII', 'CI  ER', 0.162, 100.0, 1807434.0)
# ('Financ e Outros / Fundos', 'BPFF11', 'FII ABSOLUTO', 'CI  ER', 0.273, 100.0, 4492326.0)
# ('Financ e Outros / Fundos', 'AFHI11', 'FII AFHI CRI', 'CI', 0.259, 100.0, 3019453.0)
# ('Financ e Outros / Fundos', 'ALZR11', 'FII ALIANZA', 'CI', 0.869, 100.0, 8310805.0)
# ('Financ e Outros / Fundos', 'ARCT11', 'FII ARCTIUM', 'CI', 0.324, 100.0, 3708168.0)
# ('Financ e Outros / Fundos', 'ARRI11', 'FII ATRIO', 'CI  ER', 0.095, 100.0, 11782610.0)
# ('Financ e Outros / Fundos', 'AIEC11', 'FII AUTONOMY', 'CI  ER', 0.32, 100.0, 4824987.0)
# ('Financ e Outros / Fundos', 'BARI11', 'FII BARIGUI', 'CI  ER', 0.395, 100.0, 4634191.0)
# ('Financ e Outros / Fundos', 'BBPO11', 'FII BB PRGII', 'CI  ER', 1.294, 100.0, 15919690.0)
# ('Financ e Outros / Fundos', 'BCFF11', 'FII BC FFII', 'CI  ER', 1.549, 100.0, 25186378.0)
# ('Financ e Outros / Fundos', 'BRCR11', 'FII BC FUND', 'CI  ER', 1.527, 100.0, 26638202.0)
# ('Financ e Outros / Fundos', 'BCIA11', 'FII BCIA', 'CI  ER', 0.297, 100.0, 3719038.0)
# ('Financ e Outros / Fundos', 'BCRI11', 'FII BEES CRI', 'CI  ER', 0.566, 100.0, 6257873.0)
# ('Financ e Outros / Fundos', 'BLMR11', 'FII BLUE FOF', 'CI  ER', 0.168, 100.0, 25541630.0)
# ('Financ e Outros / Fundos', 'BLMG11', 'FII BLUE LOG', 'CI  ER', 0.286, 100.0, 3810588.0)
# ('Financ e Outros / Fundos', 'BRCO11', 'FII BRESCO', 'CI  ER', 1.433, 100.0, 14778781.0)
# ('Financ e Outros / Fundos', 'BTAL11', 'FII BTG AGRO', 'CI', 0.52, 100.0, 5982736.0)
# ('Financ e Outros / Fundos', 'BTCR11', 'FII BTG CRI', 'CI  ER', 0.601, 100.0, 7418066.0)
# ('Financ e Outros / Fundos', 'BTRA11', 'FII BTG TAGR', 'CI', 0.262, 100.0, 3364559.0)
# ('Financ e Outros / Fundos', 'BTLG11', 'FII BTLG', 'CI', 1.516, 100.0, 16728960.0)
# ('Financ e Outros / Fundos', 'CPFF11', 'FII CAP REIT', 'CI  ER', 0.361, 100.0, 5449778.0)
# ('Financ e Outros / Fundos', 'CPTS11', 'FII CAPI SEC', 'CI', 2.547, 100.0, 31782814.0)
# ('Financ e Outros / Fundos', 'HGCR11', 'FII CSHG CRI', 'CI  ER', 1.799, 100.0, 19582397.0)
# ('Financ e Outros / Fundos', 'HGFF11', 'FII CSHG FOF', 'CI  ER', 0.198, 100.0, 2863597.0)
# ('Financ e Outros / Fundos', 'HGLG11', 'FII CSHG LOG', 'CI  ER', 3.486, 100.0, 23456675.0)
# ('Financ e Outros / Fundos', 'HGRU11', 'FII CSHG URB', 'CI  ER', 2.035, 100.0, 18406458.0)
# ('Financ e Outros / Fundos', 'CARE11', 'FII DEA CARE', 'CI', 0.117, 100.0, 35769919.0)
# ('Financ e Outros / Fundos', 'DEVA11', 'FII DEVANT', 'CI  ER', 1.21, 100.0, 15453965.0)
# ('Financ e Outros / Fundos', 'FEXC11', 'FII EXCELLEN', 'CI  ER', 0.474, 100.0, 6103509.0)
# ('Financ e Outros / Fundos', 'VRTA11', 'FII FATOR VE', 'CI  ER', 1.104, 100.0, 13152584.0)
# ('Financ e Outros / Fundos', 'GTWR11', 'FII G TOWERS', 'CI  ER', 0.872, 100.0, 12000000.0)
# ('Financ e Outros / Fundos', 'GGRC11', 'FII GGRCOVEP', 'CI  ERS', 0.914, 100.0, 8765433.0)
# ('Financ e Outros / Fundos', 'GALG11', 'FII GUARDIAN', 'CI  ER', 0.486, 100.0, 57485300.0)
# ('Financ e Outros / Fundos', 'HABT11', 'FII HABIT II', 'CI  ER', 0.68, 100.0, 8126783.0)
# ('Financ e Outros / Fundos', 'HCTR11', 'FII HECTARE', 'CI  ER', 1.982, 100.0, 22084202.0)
# ('Financ e Outros / Fundos', 'HGBS11', 'FII HEDGEBS', 'CI  ER', 1.812, 100.0, 10000000.0)
# ('Financ e Outros / Fundos', 'HGRE11', 'FII HG REAL', 'CI  ER', 1.393, 100.0, 11817767.0)
# ('Financ e Outros / Fundos', 'HSAF11', 'FII HSI CRI', 'CI  ER', 0.136, 100.0, 1773624.0)
# ('Financ e Outros / Fundos', 'HSLG11', 'FII HSI LOG', 'CI  ER', 1.057, 100.0, 12660067.0)
# ('Financ e Outros / Fundos', 'HSML11', 'FII HSI MALL', 'CI  ER', 1.246, 100.0, 15780613.0)
# ('Financ e Outros / Fundos', 'HFOF11', 'FII HTOPFOF3', 'CI  ER', 1.534, 100.0, 23000000.0)
# ('Financ e Outros / Fundos', 'FIIB11', 'FII INDL BR', 'CI  ER', 0.294, 100.0, 685000.0)
# ('Financ e Outros / Fundos', 'IRDM11', 'FII IRIDIUM', 'CI  ER', 3.181, 100.0, 36044581.0)
# ('Financ e Outros / Fundos', 'JSRE11', 'FII JS REAL', 'CI  ER', 1.506, 100.0, 20767328.0)
# ('Financ e Outros / Fundos', 'KISU11', 'FII KILIMA', 'CI  ER', 0.315, 100.0, 44196050.0)
# ('Financ e Outros / Fundos', 'KNRI11', 'FII KINEA', 'CI  ER', 3.03, 100.0, 24157121.0)
# ('Financ e Outros / Fundos', 'KNHY11', 'FII KINEA HY', 'CI  ER', 1.615, 100.0, 18490843.0)
# ('Financ e Outros / Fundos', 'KNIP11', 'FII KINEA IP', 'CI  ER', 6.724, 100.0, 80279611.0)
# ('Financ e Outros / Fundos', 'KNCR11', 'FII KINEA RI', 'CI  ER', 3.912, 100.0, 43861253.0)
# ('Financ e Outros / Fundos', 'KNSC11', 'FII KINEA SC', 'CI  ER', 1.038, 100.0, 13275794.0)
# ('Financ e Outros / Fundos', 'KFOF11', 'FII KINEAFOF', 'CI  ER', 0.345, 100.0, 4533315.0)
# ('Financ e Outros / Fundos', 'NSLU11', 'FII LOURDES', 'CI  ER', 0.185, 100.0, 1293286.0)
# ('Financ e Outros / Fundos', 'MALL11', 'FII MALLS BP', 'CI  ER', 0.919, 100.0, 9413575.0)
# ('Financ e Outros / Fundos', 'MCCI11', 'FII MAUA', 'CI', 1.635, 100.0, 18899883.0)
# ('Financ e Outros / Fundos', 'MCHF11', 'FII MAUA HF', 'CI', 0.263, 100.0, 32307646.0)
# ('Financ e Outros / Fundos', 'MXRF11', 'FII MAXI REN', 'CI  ER', 2.062, 100.0, 226039663.0)
# ('Financ e Outros / Fundos', 'MFII11', 'FII MERITO I', 'CI  ER', 0.361, 100.0, 4146900.0)
# ('Financ e Outros / Fundos', 'MGFF11', 'FII MOGNO', 'CI  ER', 0.512, 100.0, 9050620.0)
# ('Financ e Outros / Fundos', 'MORE11', 'FII MORE RE', 'CI', 0.147, 100.0, 2319115.0)
# ('Financ e Outros / Fundos', 'NCHB11', 'FII NCH BR', 'CI  ERS', 0.15, 100.0, 1821362.0)
# ('Financ e Outros / Fundos', 'OUJP11', 'FII OURI JPP', 'CI  ER', 0.277, 100.0, 3252384.0)
# ('Financ e Outros / Fundos', 'PATL11', 'FII PATR LOG', 'CI  ER', 0.34, 100.0, 4991535.0)
# ('Financ e Outros / Fundos', 'PLCR11', 'FII PLURAL R', 'CI  ER', 0.162, 100.0, 2109169.0)
# ('Financ e Outros / Fundos', 'PORD11', 'FII POLO CRI', 'CI  ER', 0.309, 100.0, 3728375.0)
# ('Financ e Outros / Fundos', 'QAGR11', 'FII QUASAR A', 'CI  ER', 0.211, 100.0, 5040000.0)
# ('Financ e Outros / Fundos', 'RBRL11', 'FII RBR LOG', 'CI  ER', 0.525, 100.0, 6687035.0)
# ('Financ e Outros / Fundos', 'RBRY11', 'FII RBR PCRI', 'CI  ER', 0.554, 100.0, 6374096.0)
# ('Financ e Outros / Fundos', 'RBRP11', 'FII RBR PROP', 'CI  ER', 0.595, 100.0, 12179186.0)
# ('Financ e Outros / Fundos', 'RBRF11', 'FII RBRALPHA', 'CI  ER', 0.894, 100.0, 13680770.0)
# ('Financ e Outros / Fundos', 'RBRR11', 'FII RBRHGRAD', 'CI  ER', 1.052, 100.0, 13438908.0)
# ('Financ e Outros / Fundos', 'RECR11', 'FII REC RECE', 'CI  ER', 2.079, 100.0, 26441650.0)
# ('Financ e Outros / Fundos', 'RECT11', 'FII REC REND', 'CI  ER', 0.435, 100.0, 8543493.0)
# ('Financ e Outros / Fundos', 'RBFF11', 'FII RIOB FF', 'CI  ER', 0.185, 100.0, 3749215.0)
# ('Financ e Outros / Fundos', 'RCRB11', 'FII RIOB RC', 'CI  ER', 0.443, 100.0, 3690695.0)
# ('Financ e Outros / Fundos', 'RBVA11', 'FII RIOB VA', 'CI  ER', 0.955, 100.0, 11588199.0)
# ('Financ e Outros / Fundos', 'RZAK11', 'FII RIZA AKN', 'CI  ES', 0.44, 100.0, 5007599.0)
# ('Financ e Outros / Fundos', 'RZTR11', 'FII RIZA TX', 'CI  ER', 1.003, 100.0, 11048018.0)
# ('Financ e Outros / Fundos', 'SADI11', 'FII SANT PAP', 'CI  ER', 0.258, 100.0, 3180207.0)
# ('Financ e Outros / Fundos', 'SARE11', 'FII SANT REN', 'CI  ER', 0.603, 100.0, 9234329.0)
# ('Financ e Outros / Fundos', 'SDIL11', 'FII SDI LOG', 'CI  ER', 0.546, 100.0, 6395050.0)
# ('Financ e Outros / Fundos', 'SPTW11', 'FII SP DOWNT', 'CI  ER', 0.069, 100.0, 1798000.0)
# ('Financ e Outros / Fundos', 'SNCI11', 'FII SUNO CRI', 'CI', 0.363, 100.0, 4104000.0)
# ('Financ e Outros / Fundos', 'SNFF11', 'FII SUNOFOFI', 'CI', 0.216, 100.0, 2775000.0)
# ('Financ e Outros / Fundos', 'TGAR11', 'FII TG ATIVO', 'CI  ER', 1.717, 100.0, 15336755.0)
# ('Financ e Outros / Fundos', 'TORD11', 'FII TORDE EI', 'CI  ER', 0.249, 100.0, 35051354.0)
# ('Financ e Outros / Fundos', 'TRXF11', 'FII TRX REAL', 'CI  ER', 0.943, 100.0, 9826045.0)
# ('Financ e Outros / Fundos', 'URPR11', 'FII URCA REN', 'CI  ER', 1.062, 100.0, 11858246.0)
# ('Financ e Outros / Fundos', 'VGHF11', 'FII VALOR HE', 'CI  ER', 0.604, 100.0, 72889247.0)
# ('Financ e Outros / Fundos', 'VGIP11', 'FII VALORAIP', 'CI', 0.941, 100.0, 11787247.0)
# ('Financ e Outros / Fundos', 'VGIR11', 'FII VALREIII', 'CI', 0.676, 100.0, 75707660.0)
# ('Financ e Outros / Fundos', 'CVBI11', 'FII VBI CRI', 'CI  ER', 0.893, 100.0, 11010228.0)
# ('Financ e Outros / Fundos', 'LVBI11', 'FII VBI LOG', 'CI  ER', 1.105, 100.0, 11775177.0)
# ('Financ e Outros / Fundos', 'PVBI11', 'FII VBI PRI', 'CI  ERS', 0.854, 100.0, 10039493.0)
# ('Financ e Outros / Fundos', 'RVBI11', 'FII VBI REIT', 'CI  ER', 0.098, 100.0, 1440000.0)
# ('Financ e Outros / Fundos', 'VCJR11', 'FII VECTIS', 'CI  ER', 1.22, 100.0, 14723970.0)
# ('Financ e Outros / Fundos', 'VSLH11', 'FII VERS CRI', 'CI  ER', 0.241, 100.0, 29864091.0)
# ('Financ e Outros / Fundos', 'VIFI11', 'FII VINCI IF', 'CI  ER', 0.054, 100.0, 8089190.0)
# ('Financ e Outros / Fundos', 'VIUR11', 'FII VINCI IU', 'CI  ER', 0.193, 100.0, 26946220.0)
# ('Financ e Outros / Fundos', 'VILG11', 'FII VINCI LG', 'CI  ER', 1.394, 100.0, 14997396.0)
# ('Financ e Outros / Fundos', 'VINO11', 'FII VINCI OF', 'CI  ER', 0.737, 100.0, 16565259.0)
# ('Financ e Outros / Fundos', 'VISC11', 'FII VINCI SC', 'CI  ER', 1.773, 100.0, 17696234.0)
# ('Financ e Outros / Fundos', 'VTLT11', 'FII VOT LOG', 'CI  ER', 0.18, 100.0, 2115000.0)
# ('Financ e Outros / Fundos', 'XPCI11', 'FII XP CRED', 'CI  ER', 0.681, 100.0, 8701552.0)
# ('Financ e Outros / Fundos', 'XPIN11', 'FII XP INDL', 'CI', 0.517, 100.0, 7150422.0)
# ('Financ e Outros / Fundos', 'XPLG11', 'FII XP LOG', 'CI  ER', 2.533, 100.0, 27101061.0)
# ('Financ e Outros / Fundos', 'XPML11', 'FII XP MALLS', 'CI', 1.934, 100.0, 21133278.0)
# ('Financ e Outros / Fundos', 'XPPR11', 'FII XP PROP', 'CI  ER', 0.246, 100.0, 7316171.0)
# ('Financ e Outros / Fundos', 'XPSF11', 'FII XP SELEC', 'CI  ER', 0.288, 100.0, 43302140.0)

# %%
df_ifix  = ifix_cursor = sql_conn.execute("SELECT * FROM public.ifix_b3")

# %%
#criar index na tabela 
sql_conn.execute(" ALTER TABLE PUBLIC.ifix_b3 add CONSTRAINT pk_ifix_b3 PRIMARY KEY (cod)")

# %%
#select tabela converter para dataframe
df_ifix = pd.read_sql(""" SELECT * FROM public.ifix_b3 """, sql_conn)

# %%
#select com where e converter para dataframe
df_ifix_one = pd.read_sql(""" SELECT * FROM public.ifix_b3  where "cod" = 'ARCT11' """, sql_conn)

# %%
df_ifix_one
# Out:
#                     segment     cod        asset type   part  partAcum  \
# 0  Financ e Outros / Fundos  ARCT11  FII ARCTIUM   CI  0.324     100.0
#
#    theoricalQty
# 0       3708168

# %%
df_ifix
# Out:
#                       segment     cod         asset    type   part  partAcum  \
# 0    Financ e Outros / Fundos  CACR11  CARTESIA FII  CI  ER  0.162     100.0
# 1    Financ e Outros / Fundos  BPFF11  FII ABSOLUTO  CI  ER  0.273     100.0
# 2    Financ e Outros / Fundos  AFHI11  FII AFHI CRI      CI  0.259     100.0
# 3    Financ e Outros / Fundos  ALZR11   FII ALIANZA      CI  0.869     100.0
# 4    Financ e Outros / Fundos  ARCT11   FII ARCTIUM      CI  0.324     100.0
# ..                        ...     ...           ...     ...    ...       ...
# 103  Financ e Outros / Fundos  XPIN11   FII XP INDL      CI  0.517     100.0
# 104  Financ e Outros / Fundos  XPLG11    FII XP LOG  CI  ER  2.533     100.0
# 105  Financ e Outros / Fundos  XPML11  FII XP MALLS      CI  1.934     100.0
# 106  Financ e Outros / Fundos  XPPR11   FII XP PROP  CI  ER  0.246     100.0
# 107  Financ e Outros / Fundos  XPSF11  FII XP SELEC  CI  ER  0.288     100.0
#
#      theoricalQty
# 0         1807434
# 1         4492326
# 2         3019453
# 3         8310805
# 4         3708168
# ..            ...
# 103       7150422
# 104      27101061
# 105      21133278
# 106       7316171
# 107      43302140
#
# [108 rows x 7 columns]

# %% [markdown]
# #Buscar todas as empresas listadas na B3

# %%
def getAllCompanyB3(pageN=1,pageS=9999):
  
    params = {"language":"pt-br","pageNumber":pageN,"pageSize":pageS}
    # codifica os parâmetros em base64
    params = bytes(str(params), encoding="ascii")
    string = b64encode(params)
    string = string.decode()
    r = requests.get('https://sistemaswebb3-listados.b3.com.br/listedCompaniesProxy/CompanyCall/GetInitialCompanies/'+ string)

    return r.json()

# %%
#resultado da API
result = getAllCompanyB3()

# %%
df_allCompany = pd.DataFrame.from_dict(result['results'])

# %%
#converter colunas para formato desejado
df_allCompany['codeCVM']= df_allCompany['codeCVM'].str.replace(',', '.',regex=True).astype(int)
df_allCompany['marketIndicator']= df_allCompany['marketIndicator'].str.replace(',', '.',regex=True).astype(int)
df_allCompany['dateListing'] = df_allCompany['dateListing'].str.replace('9999', '1900',regex=True).astype('datetime64[ns]')
df_allCompany['type'] = df_allCompany['type'].str.replace('.', '',regex=True).astype(int)
#df_allCompany['dateListing'] = df_allCompany['dateListing'].apply(lambda x: (parser.parse(x.replace('9999','1900')))).astype('datetime64[ns]')

# %%
df_allCompany.dtypes
# Out:
# codeCVM                     int64
# issuingCompany             object
# companyName                object
# tradingName                object
# cnpj                       object
# marketIndicator             int64
# typeBDR                    object
# dateListing        datetime64[ns]
# status                     object
# segment                    object
# segmentEng                 object
# type                        int64
# market                     object
# dtype: object

# %%
df_allCompany.rename(columns = {'codeCVM':'codecvm'}, inplace = True)

# %%
from sqlalchemy.sql.sqltypes import VARCHAR,INT
#inserir no tabela
dtype = {'codecvm': INT,
         'issuingCompany':VARCHAR(10),
         'companyName':VARCHAR(200),
         'tradingName':VARCHAR(50),
         'marketIndicator':INT,
         'typeBDR':VARCHAR(20),
         'dateListing':DateTime,
         'status': VARCHAR(1),
         'segment':	VARCHAR(100),
         'segmentEng':VARCHAR(100),
         'type':INT,
         'market':VARCHAR(20)
         } 

df_allCompany.to_sql('company_b3',sql_conn,schema='public',if_exists='append',index = False, method="multi",chunksize=999,dtype= dtype)

# %%
pd.read_sql(" select codecvm from PUBLIC.company_b3 ",sql_conn)
# Out:
#       codecvm issuingCompany  \
# 0       25291           RRRP
# 1      908830           TZRD
# 2       16284           QVQP
# 3      904110           GRDR
# 4      901082           BODY
# ...       ...            ...
# 2251   914804           ZZDT
# 2252    24317           ZAMP
# 2253   915249           ZTIX
# 2254   909655           ZMPT
# 2255   909648           ZION
#
#                                             companyName   tradingName  \
# 0                           3R PETROLEUM ÓLEO E GÁS S.A  3R PETROLEUM
# 1             3Z REALTY DESENVOLVIMENTO IMOBILIARIO S/A      3ZREALTY
# 2                                524 PARTICIPACOES S.A.  524 PARTICIP
# 3                 A  GERADORA  ALUGUEL DE MAQUINAS S.A.      GERADORA
# 4                         A BODYTECH PARTICIPACOES S.A.      BODYTECH
# ...                                                 ...           ...
# 2251  Z.A DIGITAL SP SIST. ESTACIONAMENTO ROTARIVO S.A.   Z.A DIGITAL
# 2252                                          ZAMP S.A.     ZAMP S.A.
# 2253                              ZATIX TECNOLOGIA S.A.  ZATIX TECNOL
# 2254                              ZEMA CIA. DE PETROLEO          ZEMA
# 2255                                  ZION CAPITAL S.A.   ZIONCAPITAL
#
#                 cnpj  marketIndicator typeBDR dateListing status  \
# 0     12091809000155               18          2020-09-11      A
# 1      8145855000112                1          1900-12-31      A
# 2      1851771000155                7          1998-11-09      A
# 3     33845322000190                1          1900-12-31      A
# 4      7737623000190                1          1900-12-31      A
# ...              ...              ...     ...         ...    ...
# 2251  35993098000100                1          1900-12-31      A
# 2252  13574594000196               18          2017-12-14      A
# 2253   3585974000172                1          1900-12-31      A
# 2254    647154000170                1          1900-12-31      A
# 2255  27080444000130                1          1900-12-31      A
#
#                                 segment  \
# 0     Exploração. Refino e Distribuição
# 1                     Não Classificados
# 2                                Outros
# 3                     Não Classificados
# 4                     Não Classificados
# ...                                 ...
# 2251                  Não Classificados
# 2252            Restaurante e Similares
# 2253                  Não Classificados
# 2254                  Não Classificados
# 2255                  Não Classificados
#
#                                   segmentEng  type market
# 0     Exploration. Refining and Distribution     1     NM
# 1                             Not Classified     7
# 2                                     Others     1     MB
# 3                             Not Classified     7
# 4                             Not Classified     7
# ...                                      ...   ...    ...
# 2251                          Not Classified     7
# 2252                Restaurants and Similars     1     NM
# 2253                          Not Classified     7
# 2254                          Not Classified     7
# 2255                          Not Classified     7
#
# [2256 rows x 13 columns]

# %%
#criar index
#criar index na tabela 
sql_conn.execute(" ALTER TABLE PUBLIC.company_b3 add CONSTRAINT pk_company_b3 PRIMARY KEY (codecvm) ")

# %% [markdown]
# #buscar detalhes das empresas

# %%
def getDetailCompany(codeCVM):
  
    params = {"codeCVM":codeCVM,"language":"pt-br"}
    # codifica os parâmetros em base64
    params = bytes(str(params), encoding="ascii")
    string = b64encode(params)
    string = string.decode()
    r = requests.get('https://sistemaswebb3-listados.b3.com.br/listedCompaniesProxy/CompanyCall/GetDetail/'+ string)

    return r.json()

# %%
sql = "SELECT codecvm from PUBLIC.company_b3  WHERE codecvm != 26700 AND codecvm NOT IN ( SELECT codecvm FROM PUBLIC.detail_company_b3) LIMIT 500 "

cvms = pd.read_sql(sql,sql_conn)

# %%
cvms.shape
# Out:
# (457, 1)

# %%
from sqlalchemy.sql.sqltypes import VARCHAR,INT,FLOAT,DateTime,TEXT,NUMERIC,JSON
dtype = {'issuingcompany':VARCHAR(10),
         'companyName':VARCHAR(200),
         'tradingName':VARCHAR(100),
         'CNPJ':VARCHAR(20),
         'industryClassification': VARCHAR(200),
         'industryClassificationEng': VARCHAR(200),
         'activity':VARCHAR(200),
         'website':VARCHAR(100),
         'hasQuotation':VARCHAR(100),
         'status': VARCHAR(1),
         'marketIndicator':INT,
         'institutionCommon':VARCHAR(100),
         'institutionPreferred':VARCHAR(100),
        'code':	VARCHAR(10),
        'codecvm': INT,
        'lastdate':DateTime,
        'otherCodes':	JSON,
        'hasEmissions':Boolean,
        'hasBDR':Boolean,
        'typeBDR':VARCHAR(100),
        'describleCategoryBVMF':VARCHAR(200)
      }

# %%
import time
from datetime import datetime

all_detail_company = pd.DataFrame()
err_cvm = []
print(datetime.today())
for i in cvms.index:
    cod = cvms['codecvm'][i]
    print(cod)
    time.sleep(1)
    result = getDetailCompany(cod)
    #separar em as chaves e depois os valores para montar o dataframe

    if (len(result) == 0):
       err_cvm.append(cod)
       continue

    values = result.values()
    keys = result.keys()

    df_detCompany = pd.DataFrame([values],columns=keys)

    #converter colunas para formato desejado
    df_detCompany['codeCVM']= df_detCompany['codeCVM'].str.replace(',', '.',regex=True).astype(int)
    df_detCompany['marketIndicator']= df_detCompany['marketIndicator'].str.replace(',', '.',regex=True).astype(int)
    df_detCompany['lastDate'] = df_detCompany['lastDate'].astype('datetime64[ns]')
    df_detCompany.rename(columns = {'codeCVM':'codecvm','issuingCompany':'issuingcompany'}, inplace = True)

    #df_allCompany['dateListing'] = df_allCompany['dateListing'].apply(lambda x: (parser.parse(x.replace('9999','1900')))).astype('datetime64[ns]')

    all_detail_company =  pd.concat([all_detail_company,df_detCompany])
    print(cod)
all_detail_company.to_sql('detail_company_b3',sql_conn,schema='public',if_exists='append',index = False, method="multi",chunksize=999,dtype=dtype)
    
print(datetime.today())
print('empresa não encontrada')
print(err_cvm)
# Out:
# 2022-11-12 18:01:23.500812
# 913376
# 913376
# 913384
# 913384
# 913392
# 913392
# 913400
# 913400
# 913418
# 913418
# 913426
# 913426
# 913434
# 913434
# 913442
# 913442
# 913459
# 913459
# 913467
# 913467
# 913475
# 913475
# 913483
# 913483
# 913491
# 913491
# 913509
# 913509
# 913517
# 913517
# 913525
# 913525
# 913533
# 913533
# 913541
# 913541
# 913558
# 913558
# 913566
# 917513
# 917514
# 917515
# 917517
# 917518
# 917519
# 917520
# 917521
# 917522
# 917523
# 917525
# 917526
# 917527
# 917528
# 917529
# 917530
# 917531
# 917533
# 917534
# 917535
# 917536
# 917537
# 917538
# 917539
# 917541
# 917542
# 917543
# 917544
# 917545
# 917546
# 2022-11-12 18:13:53.155384
# codigo com erro
# [916153, 916155, 916161, 916163, 916171, 916172, 916173, 916174, 916175, 916188, 916189, 916196, 916197, 916205, 916213, 916221, 916239, 916247, 916254, 916262, 916270, 916288, 916296, 916304, 916312, 916320, 916338, 916346, 916353, 916361, 916379, 916382, 916387, 916390, 916395, 916403, 916411, 916429, 916437, 916445, 916452, 916460, 916478, 916486, 916494, 916502, 916551, 916569, 916577, 916585, 916593, 916595, 916601, 916619, 916627, 916633, 916635, 916641, 916643, 916700, 916714, 916718, 916722, 916730, 916749, 916757, 916765, 916773, 916781, 916791, 916809, 916811, 916825, 916833, 916838, 916841, 916846, 916854, 916858, 916862, 916870, 916889, 916897, 916908, 916919, 916927, 916935, 916943, 916951, 916957, 916965, 916978, 916986, 916994, 917005, 917013, 917021, 917039, 917047, 917054, 917062, 917070, 917088, 917096, 917104, 917112, 917120, 917133, 917141, 917153, 917161, 917179, 917187, 917195, 917203, 917229, 917237, 917245, 917252, 917260, 917278, 917286, 917294, 917302, 917310, 917328, 917336, 917344, 917351, 917362, 917370, 917389, 917397, 917401, 917450, 917452, 917453, 917454, 917455, 917456, 917457, 917458, 917459, 917461, 917462, 917463, 917464, 917465, 917466, 917467, 917468, 917469, 917470, 917471, 917472, 917473, 917474, 917475, 917476, 917477, 917479, 917480, 917481, 917482, 917483, 917484, 917485, 917487, 917488, 917489, 917490, 917491, 917492, 917493, 917495, 917496, 917497, 917498, 917499, 917500, 917501, 917502, 917503, 917504, 917505, 917506, 917507, 917509, 917510, 917511, 917512, 917513, 917514, 917515, 917517, 917518, 917519, 917520, 917521, 917522, 917523, 917525, 917526, 917527, 917528, 917529, 917530, 917531, 917533, 917534, 917535, 917536, 917537, 917538, 917539, 917541, 917542, 917543, 917544, 917545, 917546]

# %%
#df_detCompany['otherCodes']=  df_detCompany['otherCodes'].apply(lambda x: ((x.replace("[","").replace("]",""))))
#import json
#df_detCompany['otherCodes'] = df_detCompany['otherCodes'].apply(json.dumps)

# %% [markdown]
# #importar dados dos fundos imobiliarios

# %%
import requests
from base64 import b64encode
# Função para obter os proventos
def getFii(pageN=1,pageS=999):
  
    # cria os parâmetros com o trading name

    params = {"typeFund":7,"pageNumber":pageN,"pageSize":pageS}
    
    # codifica os parâmetros em base64
    params = bytes(str(params), encoding="ascii")
    string = b64encode(params)
    string = string.decode()

    r = requests.get('https://sistemaswebb3-listados.b3.com.br/fundsProxy/fundsCall/GetListedFundsSIG/'+string)
    return r.json()

# %%
fii = getFii()

# %%
df_all_fii = pd.DataFrame.from_dict(fii['results'])

# %%
df_all_fii.rename(columns = {'fundName':'fundname','companyName':'companyname'}, inplace = True)

# %%
#from sqlalchemy.sql import VARCHAR
dtype = {'segment':VARCHAR(10),
         'acronym':VARCHAR(50),
          'fundname':VARCHAR(50),
         'companyname':VARCHAR(200),
         'cnpj':VARCHAR(20),
      }

# %%
#gravar no banco SQL
df_all_fii.to_sql('fii_b3',sql_conn,schema='public',if_exists='append',index = False, method="multi",chunksize=999,dtype=dtype)

# %% [markdown]
# Buscar detalhes dos fundos imobiliarios

# %%
import requests
from base64 import b64encode
# Função para obter os proventos
def getDetailFii(acronym):
  
    # codFII: "ASRF"
    params =   {"typeFund":7,"identifierFund":acronym}
    # codifica os parâmetros em base64
    params = bytes(str(params), encoding="ascii")
    string = b64encode(params)
    string = string.decode()

    r = requests.get('https://sistemaswebb3-listados.b3.com.br/fundsProxy/fundsCall/GetDetailFundSIG/'+string)
    return r.json()

# %%
df = getDetailFii('KNHY')

# %%
#buscar nome dos fii na base de dados
# buscar todos empresas cadastrada na base de dados para fazer o SPLIT no campo industryclassification !!
sql = " SELECT distinct(acronym) FROM PUBLIC.fii_b3 WHERE acronym NOT IN (SELECT distinct(acronym) FROM  PUBLIC.detail_fii_b3)  "
def_fii = pd.read_sql(sql,sql_conn)

# %%
def_fii
# Out:
# Empty DataFrame
# Columns: [acronym]
# Index: []

# %%
from sqlalchemy.sql.sqltypes import VARCHAR,INT,FLOAT,DateTime,TEXT,NUMERIC,JSON
dtype = {'acronym': VARCHAR(10),
          'tradingname': VARCHAR(30),
          'tradingcode': VARCHAR(10),
          'tradingcodeothers': VARCHAR(50),
          'cnpj': VARCHAR(20),
          'classification': VARCHAR(200),
          'website': VARCHAR(100),
          'fundaddress': VARCHAR(200),
          'fundphonenumberddd': VARCHAR(20),
          'fundphonenumber': VARCHAR(20),
          'fundphonenumberfax': VARCHAR(20),
          'positionmanager':  VARCHAR(50),
          'managername':  VARCHAR(50),
          'companyaddress': VARCHAR(200),
          'companyphonenumberddd': VARCHAR(10),
          'companyphonenumber': VARCHAR(20),
          'companyphonenumberfax': VARCHAR(20),
          'companyemail': VARCHAR(100),
          'companyname': VARCHAR(100),
          'quotacount': INT,
          'quotadateapproved': DateTime,
          'typefnet': VARCHAR(50),
          'codes': JSON,
          'codesother': VARCHAR(50),
          'segment': VARCHAR(50)
          }

# %%
#key = list(df_fii.columns)
#value = [x.lower() for x in list(df_fii.columns)]
##columns = pd.DataFrame([value],columns=key).to_dict('records')[0]

import time
from datetime import datetime

err_det_fii = []
print(datetime.today())
for i in def_fii.index:
    cod = def_fii['acronym'][i]
    print(cod)
    time.sleep(2)
    #buscar detalhes dos fundos
    result = getDetailFii(cod)
  

    if (len(result['detailFund']) == 0):
       err_det_fii.append(cod)
       continue
    #renomear colunas com em lower case
    columns = { 'acronym': 'acronym',
               'tradingName': 'tradingname',
              'tradingCode': 'tradingcode',
              'tradingCodeOthers': 'tradingcodeothers',
              'cnpj': 'cnpj',
              'classification': 'classification',
              'webSite': 'website',
              'fundAddress': 'fundaddress',
              'fundPhoneNumberDDD': 'fundphonenumberddd',
              'fundPhoneNumber': 'fundphonenumber',
              'fundPhoneNumberFax': 'fundphonenumberfax',
              'positionManager': 'positionmanager',
              'managerName': 'managername',
              'companyAddress': 'companyaddress',
              'companyPhoneNumberDDD': 'companyphonenumberddd',
              'companyPhoneNumber': 'companyphonenumber',
              'companyPhoneNumberFax': 'companyphonenumberfax',
              'companyEmail': 'companyemail',
              'companyName': 'companyname',
              'quotaCount': 'quotacount',
              'quotaDateApproved': 'quotadateapproved',
              'typeFNET': 'typefnet',
              'codes': 'codes',
              'codesOther': 'codesother',
              'segment': 'segment' }

    df_fii = pd.DataFrame([result['detailFund']])
    df_fii.rename(columns = columns, inplace = True)
    df_fii['cnpj'] =  df_fii['cnpj'].astype(int)
    df_fii['quotacount'] =  df_fii['quotacount'].astype(int)
    df_fii['quotadateapproved'] = pd.to_datetime( df_fii['quotadateapproved'], errors ='coerce')
    df_fii.fillna('')
    df_fii.to_sql('detail_fii_b3',sql_conn,schema='public',if_exists='append',index = False, method="multi",dtype=dtype)
    
      
print(datetime.today())
print('não existem detalhes')
print(err_det_fii)
# Out:
# 2022-11-18 21:41:33.800859
# ABCP
# FLMA
# MOFF
# LFTT
# HUSI
# CJFI
# SHDP
# BCRI
# HLOG
# RBRY
# JFLL
# SFND
# CCME
# GURB
# VIDS
# FIIP
# BVAR
# XPCI
# PLOG
# HGCR
# VLJS
# TEPP
# RBVA
# FMOF
# GGRC
# KNHY
# BTSG
# SIGR
# RBHG
# VLIQ
# VCJR
# VDSV
# TSNC
# RBLG
# CTNP
# SOLR
# RBRM
# AFHI
# MTOF
# OURE
# MMPD
# AURB
# BRCR
# DEVA
# CYCR
# PRSN
# JPPA
# ARRI
# RCKF
# FIIB
# BRIP
# ALZM
# CCRF
# KISU
# YUFI
# NAVT
# PRTS
# FPAB
# MORC
# JCDB
# TCIN
# IRDM
# FAMB
# XPIN
# HTMX
# FAGL
# EVBI
# ZAVI
# HCHG
# CXCE
# TRXF
# PRSV
# JTPR
# QAMI
# HCRI
# XPPR
# IDFI
# FCFL
# CEOC
# TRXB
# KFOF
# VSLH
# RRCI
# SPVJ
# CPFF
# FLRP
# IBCR
# RVBI
# FEXC
# BARI
# BMLC
# BRSE
# DVFF
# IRIM
# EDGA
# HGFF
# MVFI
# NEWL
# RBIR
# HCTR
# RECX
# LRDI
# PQAG
# BRCO
# BBRC
# TGAR
# FIGS
# BZEL
# RPRI
# PNDL
# BBPO
# 2022-11-18 21:49:07.211682
# não existem detalhes
# []

# %% [markdown]
# # Atualizar o Setor/Subsetor e Segmento da empresas listada na B3

# %%
# buscar todos empresas cadastrada na base de dados para fazer o SPLIT no campo industryclassification !!

sql = " SELECT * FROM PUBLIC.detail_company_b3  WHERE industryclassification IS NOT NULL "

empresas = pd.read_sql(sql,sql_conn)

# %%
empresas[["setor","subsetor","segmento"]] = empresas["industryclassification"].str.split("/",expand=True)

# %%
empresas
# Out:
#      issuingcompany                                        companyname  \
# 0              WEGE                                           WEG S.A.
# 1              ENER  ENERGISA MATO GROSSO DO SUL - DIST DE ENERGIA ...
# 2              ETER                                       ETERNIT S.A.
# 3              EUCA                  EUCATEX S.A. INDUSTRIA E COMERCIO
# 4              FIGE                           INVESTIMENTOS BEMGE S.A.
# ...             ...                                                ...
# 2029           TCUL      TERRA DE CULTIVO INDS. DE FERT. E RACOES LTDA
# 2030           DETR  TRAVESSIA E DELTA SEC. DE CREDITOS MERCANTIS S.A.
# 2031           ALEX                    ALEX ENERGIA PARTICIPACOES S.A.
# 2032           THAP               THALASSIUS A033.21 PARTICIPAÇÕES S.A
# 2033           EMSA                                         EMS   S.A.
#
#        tradingname            cnpj  \
# 0              WEG  84429695000111
# 1          ENERSUL  15413826000150
# 2          ETERNIT  61092037000181
# 3          EUCATEX  56643018000166
# 4     INVEST BEMGE  01548981000179
# ...            ...             ...
# 2029  TERRAINDSLTD  06105854000119
# 2030  TRAVDELTASEC  41719223000190
# 2031  ALEXENERGIAP  31908068000105
# 2032  THALASSIUSA0  42152864000179
# 2033           EMS  57507378000365
#
#                                  industryclassification  \
# 0     Bens Industriais / Máquinas e Equipamentos / M...
# 1     Utilidade Pública / Energia Elétrica / Energia...
# 2     Bens Industriais / Construção e Engenharia / P...
# 3         Materiais Básicos / Madeira e Papel / Madeira
# 4                              Outros / Outros / Outros
# ...                                                 ...
# 2029  Não Classificados / Não Classificado / Não Cla...
# 2030  Não Classificados / Não Classificado / Não Cla...
# 2031  Não Classificados / Não Classificado / Não Cla...
# 2032  Não Classificados / Não Classificado / Não Cla...
# 2033  Não Classificados / Não Classificado / Não Cla...
#
#      industryclassificationEng  \
# 0                         None
# 1                         None
# 2                         None
# 3                         None
# 4                         None
# ...                        ...
# 2029                      None
# 2030                      None
# 2031                      None
# 2032                      None
# 2033                      None
#
#                                                activity  \
# 0     A WEG SA é uma sociedade de participação não o...
# 1                      Distribuição de energia elétrica
# 2     Industrialização e comercialização de produtos...
# 3     Indústria e Comércio de chapas de fibra de mad...
# 4                                         Investimentos
# ...                                                 ...
# 2029                                               None
# 2030                                               None
# 2031                                               None
# 2032                                               None
# 2033                                               None
#
#                             website hasquotation status  ...  \
# 0                    www.weg.net/br         None      A  ...
# 1                www.enersul.com.br         None      A  ...
# 2             www.eternit.com.br/ri         None      A  ...
# 3             www.eucatex.com.br/ri         None      A  ...
# 4     www.investimentosbemge.com.br         None      A  ...
# ...                             ...          ...    ...  ...
# 2029                                        None      A  ...
# 2030                                        None      A  ...
# 2031                                        None      A  ...
# 2032                                        None      A  ...
# 2033                                        None      A  ...
#
#                                              othercodes hasemissions hasbdr  \
# 0           [{'code': 'WEGE3', 'isin': 'BRWEGEACNOR0'}]        False  False
# 1                                                  None        False  False
# 2           [{'code': 'ETER3', 'isin': 'BRETERACNOR3'}]        False  False
# 3     [{'code': 'EUCA3', 'isin': 'BREUCAACNOR1'}, {'...        False  False
# 4     [{'code': 'FIGE3', 'isin': 'BRFIGEACNOR6'}, {'...        False  False
# ...                                                 ...          ...    ...
# 2029                                               None        False  False
# 2030                                               None        False  False
# 2031                                               None        False  False
# 2032                                               None        False  False
# 2033                                               None        False  False
#
#      typebdr describleCategorybvmf         datelisting            lastdate  \
# 0       None                  None 2022-11-11 23:41:58 2022-11-11 23:41:58
# 1       None                  None 2022-11-11 23:18:00 2022-11-11 23:18:00
# 2       None                  None 2022-11-11 23:18:53 2022-11-11 23:18:53
# 3       None                  None 2022-11-11 23:18:55 2022-11-11 23:18:55
# 4       None                  None 2022-11-11 23:23:25 2022-11-11 23:23:25
# ...      ...                   ...                 ...                 ...
# 2029    None                  None                 NaT 2022-11-11 23:38:14
# 2030    None                  None                 NaT 2022-11-11 23:38:58
# 2031    None                  None                 NaT 2022-11-11 23:04:38
# 2032    None                  None                 NaT 2022-11-11 23:38:22
# 2033    None                  None                 NaT 2022-11-11 23:17:43
#
#                    setor                   subsetor  \
# 0      Bens Industriais    Máquinas e Equipamentos
# 1     Utilidade Pública           Energia Elétrica
# 2      Bens Industriais    Construção e Engenharia
# 3     Materiais Básicos            Madeira e Papel
# 4                Outros                     Outros
# ...                  ...                        ...
# 2029  Não Classificados           Não Classificado
# 2030  Não Classificados           Não Classificado
# 2031  Não Classificados           Não Classificado
# 2032  Não Classificados           Não Classificado
# 2033  Não Classificados           Não Classificado
#
#                               segmento
# 0      Motores . Compressores e Outros
# 1                     Energia Elétrica
# 2             Produtos para Construção
# 3                              Madeira
# 4                               Outros
# ...                                ...
# 2029                 Não Classificados
# 2030                 Não Classificados
# 2031                 Não Classificados
# 2032                 Não Classificados
# 2033                 Não Classificados
#
# [2034 rows x 26 columns]

# %%
from sqlalchemy.sql.sqltypes import VARCHAR,INT,FLOAT,DateTime,TEXT,NUMERIC,JSON,Boolean
dtype = {'issuingcompany': VARCHAR(10),
         'companyname':VARCHAR(200),
         'tradingname':VARCHAR(100),
         'cnpj': VARCHAR(20),
         'industryclassification': VARCHAR(200),
         'industryclassificationEng': VARCHAR(200),
         'activity':VARCHAR(200),
         'website':VARCHAR(100),
         'hasquotation':VARCHAR(100),
         'status': VARCHAR(1),
         'marketindicator':INT,
         'institutioncommon':VARCHAR(100),
         'institutionpreferred':VARCHAR(100),
         'code':	VARCHAR(10),
         'codecvm': INT,
         'lastdate':DateTime,
         'othercodes':	JSON,
         'hasemissions':Boolean,
         'hasbdr':Boolean,
         'typebdr':VARCHAR(100),
         'describlecategorybvmf': VARCHAR(200),
         'setor':VARCHAR(100),
         'subsetor':VARCHAR(100),
         'segmento':VARCHAR(100)
      } 
#empresas.to_sql('detail_company_b3',sql_conn,schema='public',if_exists='replace',index = False, method="multi",dtype=dtype)

# %%
# formar tabela de setor 
sql = " SELECT distinct(setor) as descricao FROM PUBLIC.detail_company_b3  WHERE industryclassification IS NOT NULL order by setor "
df_setores = pd.read_sql(sql,sql_conn)

# %%
from sqlalchemy.sql.sqltypes import VARCHAR,INT
#criar uma coluna a partir do index
df_setores = df_setores['descricao'].str.strip()
df_setores = df_setores.rename_axis('codigo').reset_index()
#deixar o index a partir de 1
df_setores['codigo'] = df_setores['codigo']+1

dtype = {'codigo':INT,
         'descricao':VARCHAR(100)
}

#criar a tabela no banco
df_setores.to_sql('setores_b3',sql_conn,schema='public',if_exists='replace',index = False, method="multi",dtype=dtype)

# %%
# formar tabela de subserto
sql = " SELECT distinct(subsetor) as descricao FROM PUBLIC.detail_company_b3  WHERE industryclassification IS NOT NULL order by subsetor "
df_subsetores = pd.read_sql(sql,sql_conn)

# %%
df_subsetores = df_subsetores['descricao'].str.strip().replace('Não Classificados','Não Classificado').drop_duplicates()
df_subsetores = df_subsetores.rename_axis('codigo').reset_index()
df_subsetores['codigo'] = df_setores['codigo']+1
dtype = {'codigo':INT,
         'descricao':VARCHAR(100)
}
#criar a tabela no banco
df_setores.to_sql('subsetores_b3',sql_conn,schema='public',if_exists='replace',index = False, method="multi",dtype=dtype)

# %%
# criar tabela de segmentos
sql = " SELECT distinct(segmento) as descricao FROM PUBLIC.detail_company_b3  WHERE industryclassification IS NOT NULL order by segmento "
df_segmento = pd.read_sql(sql,sql_conn)

# %%
#df_segmento.groupby(['descricao']).size().sort_values()
#remover duplicadas e limpar espaço em brancos
df_segmento['descricao'] = df_segmento['descricao'].str.strip().drop_duplicates()
###
df_segmento = df_segmento.rename_axis('codigo').reset_index()
df_segmento['codigo'] = df_segmento['codigo'] + 1
dtype = {'codigo':INT,
          'descricao':VARCHAR(100)
}
# #criar a tabela no banco
df_segmento.to_sql('segmentos_b3',sql_conn,schema='public',if_exists='replace',index = False, method="multi",dtype=dtype)

# %% [markdown]
# #buscar dados dos dividendos dos ativos

# %%
def tipo_acao(tipo):
      if tipo == 'ON':
        vTipo = 3
      elif tipo == 'PN':
        vTipo = 4
      elif tipo == 'PNA':
        vTipo = 5
      elif tipo == 'PNB':
        vTipo = 6
      elif tipo == 'UNIT':
        vTipo = 11
      else:
         vTipo = ''

      return vTipo

# %%
# Função para obter os proventos
def dividendos(tradingname):
    # cria os parâmetros com o trading name
    params = {"language":"pt-br","pageNumber":1,"pageSize":99999,"tradingName":tradingname}
    # codifica os parâmetros em base64
    params = bytes(str(params), encoding="ascii")
    string = b64encode(params)
    string = string.decode()
    r = requests.get('https://sistemaswebb3-listados.b3.com.br/listedCompaniesProxy/CompanyCall/GetListedCashDividends/'+ string)

    return r.json()

# %%
# buscar tabelas de company
sql = " SELECT codecvm, tradingname, issuingcompany FROM public.company_b3 WHERE codecvm not in (SELECT  distinct(codecvm) FROM PUBLIC.dividendos_b3) AND codecvm IN  (SELECT  distinct(codecvm) FROM PUBLIC.detail_company_b3 WHERE code IS NOT null) order by codecvm "
df_company = pd.read_sql(sql,sql_conn)
df_company['tradingname']   = df_company['tradingname'].str.replace('/','').str.replace(' ','')

# %%
#list_erro =  ['HERCULES', 'HOTEISOTHON', 'ESTRELA', 'IGUATEMIS.A', 'NORDONMET', 'SPTURIS', 'WETZELSA', 'SANSUY', 'HAGASA', 'CEMEPE', 'SUZANOS.A.', 'DIBENSLSG', 'CIMS', 'P.ACUCAR-CBD', 'LITEL', 'ALLNORTE', 'FERCATLANT', '524PARTICIP', 'SUL116PART', 'SUDESTESA', 'EQTLMARANHAO', 'UPTICK', 'YBYRASA', 'BNDESPAR', 'RUMOS.A.', 'BETAPART', 'MMXMINER', 'ALLPAULISTA', 'MRSLOGIST', 'GAMAPART', 'CONFIANZASA', 'CIBRASEC', 'PROMPTPART', 'RBCAPITALRES', 'PADTEC', 'WTORREPIC', 'MENEZESCORT', 'DTCOM-DIRECT', 'BRAZILIANSC', 'INVEPAR', 'CABINDAPART', 'CONCRIOTER', 'PROMAN', 'BIOMM', 'ITAPEBI', 'SANESALTO', 'BRADESCOLSG', 'BRAZILREALT', 'TERMOPE', 'BRPR56SEC']

# %%
df_company = df_company.query('tradingname not in @list_erro')

# %%
import time
from datetime import datetime

all_div = pd.DataFrame()
err_div = []
print(datetime.today())
for i in df_company.index:
    cod = df_company['tradingname'][i]
    print(cod)
    time.sleep(2)
    result = dividendos(cod)
    
    #separar em as chaves e depois os valores para montar o dataframe

    if (len(result['results']) == 0):
       err_div.append(cod)
       continue

    df_proventos = pd.DataFrame(result['results'])
        #transformar as colunas nos types necessario

    #renomear as colunas
    df_proventos.rename(columns = {'typeStock':'typestock',
                                  'dateApproval':'dateapproval',
                                   'valueCash':'valuecash',
                                   'corporateAction':'corporateaction',
                                   'lastDatePriorEx':'lastdatepriorex',
                                   'dateClosingPricePriorExDate':'dateclosingpricepriorexdate',
                                   'closingPricePriorExDate':'closingpricepriorexdate',
                                   'quotedPerShares':'quotedpershares',
                                    'corporateActionPrice':'corporateactionprice',
                                   'lastDateTimePriorEx':'lastdatetimepriorex'}, inplace = True)
    
    df_proventos['codecvm'] = df_company['codecvm'][i]
    df_proventos['tradingname'] = df_company['tradingname'][i]
    df_proventos['code'] = df_proventos['typestock'].apply(lambda x: (df_company['issuingcompany'][i]+str(tipo_acao(x))))
    df_proventos['valuecash'] = df_proventos['valuecash'].str.replace('.','',regex=True).str.replace(',','.',regex=True).astype(float)
    
    df_proventos['closingpricepriorexdate'] = df_proventos['closingpricepriorexdate'].str.replace('.','',regex=True).str.replace(',','.',regex=True).astype(float)
    df_proventos['corporateactionprice'] = df_proventos['corporateactionprice'].str.replace('.','',regex=True).str.replace(',','.',regex=True).astype(float)
    
    #df_proventos['lastdatepriorex'] = df_proventos['lastdatepriorex'].astype('datetime64[ns]')
    df_proventos['lastdatepriorex'] = pd.to_datetime( df_proventos['lastdatepriorex'] , errors ='coerce')
    try:
       #df_proventos['dateclosingpricepriorexdate'] = df_proventos['dateclosingpricepriorexdate'].astype('datetime64[ns]')
       df_proventos['dateclosingpricepriorexdate'] = pd.to_datetime( df_proventos['dateclosingpricepriorexdate'] , errors ='coerce')
    except Exception:
      df_proventos['dateclosingpricepriorexdate'] = ''
       	
    #df_proventos['lastdatetimepriorex'] =     df_proventos['lastdatetimepriorex'].astype('datetime64[ns]')

    df_proventos['lastdatetimepriorex'] = pd.to_datetime( df_proventos['lastdatetimepriorex'] , errors ='coerce')

    #df_proventos['dateapproval'] = df_proventos['dateapproval'].astype('datetime64[ns]')
    df_proventos['dateapproval'] = pd.to_datetime( df_proventos['dateapproval'] , errors ='coerce')

    df_proventos.fillna('')

    #all_div =  pd.concat([all_div,df_proventos])

    df_proventos.to_sql('dividendos_b3',sql_conn, schema='public',if_exists='append',index = False, method="multi", dtype=dtype)

    # #criar a tabela no banco
#all_div.to_sql('dividendos_b3',sql_conn, schema='public',if_exists='append',index = False, method="multi", dtype=dtype)   
# MMXSUDESTE
# MINASARENA
# MANAUSAMBIEN
# MANDIC
# BRASOILPETRO
# MANTIQUEIRA
# MONTREAL
# MORRINHOS
# MARACANAU
# MERCANTII
# MARECHALRON
# MRLENGENHARI
# MOROCO
# MORGANSTANLE
# STAGENEBRA
# MSPARTICIPAC
# METRODABAHIA
# MTELTECSA
# METROBARRA
# METRONORTE
# MATEUS
# MULTITERMINA
# MATAVELHA
# MUDARSPESA
# MOVIDALOC
# MVPARTICIPAC
# MARISOL
# XINGUPART
# NATIXISBM
# NBCBM
# NCENERGIA
# NOTREDAME
# COMPNACIONAL
# NEERANS
# NUFARM
# NEGRESCOCFI
# NAMPONT
# NORTEBR
# NS2
# MAISSHOPPING
# NORTEENERGIA
# NATURALONE
# NOVANTS
# VENTOFORMOSO
# CHAPEUENERGI
# PONTOCOM
# NOVAVENTOS
# NVTIANGUA
# TIANGUANORTE
# OAS
# OCEANAIR
# OCEAN
# ODEBRECHTAMB
# BRKSUMARE
# BRKAMBIENTAL
# ODEBRECHTPAR
# ODEBRECHTTRA
# ODEBSA
# ODEBENER
# ORSA
# ODEBRETRANS
# ODOYAENERGIA
# VENTOARAGANO
# EOLICA2
# OESTADO
# OEAEOLICAIV
# SENANDESIII
# ODEBPARTINV
# OMEGA2
# OUROPRETO
# OURINVESTBM
# OSPINVEST
# OSX
# PACER
# PORTALEGREPA
# EOLICAPARAIS
# RECII
# PORTODOPECEM
# BAHIAPCH
# PCHHOLDING
# PEDRAII
# PEDRAI
# PDCPART
# PDL10
# RECI
# PARNAIBAGAS
# PARTPHARMA
# C2
# PIRAPORAIIEN
# PEDRARAJADAI
# POLO
# PRIMAVCONST
# PRIMEINC
# BARCASENERGI
# SALGADO
# PARNAIBAENER
# PIRAPORAIX
# PORTONAVEPAR
# PIRAPORAIVEN
# PIRAPORAVI
# ASSURUA
# LARANJEIRASI
# ASSURUAVII
# LARANJEIRASI
# ASSURUAII
# PARKEMPREE
# PROQUIGEL
# PIRAPORAIIIE
# PIRAPORAII
# PIRAPORAX
# PARQUEDALAGO
# PIRAPORAV
# PRUDENSHOPPI
# PROSIMULADOR
# PARANAIBA
# SANTFINANCEA
# POUSOALEGRE
# PNEUSOLA
# PORTOCREDCFI
# POTIGUAR
# POTAMIENERGI
# PORTONAVE
# PETRA
# PIRAPORAVII
# QUALICORPADM
# QUALICORSEG
# QUEIROZDEV
# QUEIROZGALVA
# QGALVAO
# Q1COMERCIAL
# QUEIXADA
# ATLANTICO
# RABOBANKBM
# RBCOMMERCIAL
# RBCAPHOLDING
# RIBEIRAOPRET
# PRIMEII
# REALTYIX
# RBS
# REALTYVII
# RIACHUELO
# REC2017IX
# REC2017VI
# RODLAGOS
# CONCESRODOES
# RODOVIACATAR
# REBSA
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-212-268d257d0a8b> in <module>
#       8     cod = df_company['tradingname'][i]
#       9     print(cod)
# ---> 10     time.sleep(2)
#      11     result = dividendos(cod)
#      12
#
# KeyboardInterrupt:

# %%
#all_div.to_sql('dividendos_b3',sql_conn, schema='public',if_exists='append',index = False, method="multi", dtype=dtype)
